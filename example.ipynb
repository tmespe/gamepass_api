# %%
import pandas as pd
from gamepass_fetcher import GamePass

# %%
library = GamePass()

top_games = library.top_n_reviewed(15)

# %%
top_games
# Out:
#                                                                                short_title  \
# Grand Theft Auto V                                                                   GTA V
# Undertale                                                                              NaN
# Celeste                                                                            Celeste
# DRAGON QUEST® XI S: Echoes of an Elusive Age™ -...  DRAGON QUEST XI S – Definitive Edition
# Ori and the Will of the Wisps                                Ori and the Will of the Wisps
# NieR:Automata™ BECOME AS GODS Edition                                       NieR:Automata™
# What Remains of Edith Finch                                    What Remains of Edith Finch
# Dead Cells                                                                      Dead Cells
# Slay The Spire                                                              Slay the Spire
# ...
